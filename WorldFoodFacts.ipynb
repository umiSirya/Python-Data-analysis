# %% [markdown]
# <a href="https://colab.research.google.com/github/umiSirya/General-Data-analysis/blob/main/WorldFoodFacts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd
import numpy as np
food = pd.read_csv('/content/en.openfoodfacts.org.products.tsv', delimiter='\t',low_memory=False)
food
# Out:
#               code                                                url  \
# 0             3087  http://world-en.openfoodfacts.org/product/0000...
# 1             4530  http://world-en.openfoodfacts.org/product/0000...
# 2             4559  http://world-en.openfoodfacts.org/product/0000...
# 3            16087  http://world-en.openfoodfacts.org/product/0000...
# 4            16094  http://world-en.openfoodfacts.org/product/0000...
# ...            ...                                                ...
# 37853  41129077115  http://world-en.openfoodfacts.org/product/0041...
# 37854  41129077122  http://world-en.openfoodfacts.org/product/0041...
# 37855  41129077429  http://world-en.openfoodfacts.org/product/0041...
# 37856  41129077627  http://world-en.openfoodfacts.org/product/0041...
# 37857  41129077634  http://world-en.openfoodfacts.org/product/0041...
#
#                           creator   created_t      created_datetime  \
# ...

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
food.head(5)
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
food.describe()
# Out:
#                code     created_t  last_modified_t  cities  allergens_en  \
# count  3.785800e+04  3.785800e+04     3.785800e+04     0.0           0.0
# mean   2.270552e+10  1.486903e+09     1.488082e+09     NaN           NaN
# std    1.256873e+10  1.224018e+07     7.638612e+06     NaN           NaN
# min    1.000000e+01  1.332445e+09     1.387553e+09     NaN           NaN
# 25%    1.122510e+10  1.489062e+09     1.489062e+09     NaN           NaN
# 50%    2.114002e+10  1.489071e+09     1.489072e+09     NaN           NaN
# 75%    3.225124e+10  1.489094e+09     1.489094e+09     NaN           NaN
# max    1.256420e+12  1.505686e+09     1.505686e+09     NaN           NaN
#
#        no_nutriments   additives_n  ingredients_from_palm_oil_n  \
# count            0.0  36659.000000                 36659.000000
# mean             NaN      2.253744                     0.000682
# std              NaN      2.700873                     0.026106
# ...

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
food.shape[1]
# Out:
# 163

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
food.columns[104]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
food.dtypes[104]
# Out:
# <ipython-input-12-a6b7f1f7cfe7>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   food.dtypes[104]
# dtype('float64')

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=37858, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
food.product_name[18]
# Out:
# 'Lotus Organic Brown Jasmine Rice'
